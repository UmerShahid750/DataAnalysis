# %%
import pandas as pd
import xarray as xr
import netCDF4 as nc

# %%
path = 'C:/Data/Wflow/Kurram/Kurram/artifact_data/'

# %%
nc_file = xr.open_dataset(path+'era5_orography.nc')

# %%
nc_file
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 14, latitude: 10, time: 368160)
# Coordinates:
#   * longitude  (longitude) float32 68.84 69.09 69.34 69.59 ... 71.59 71.84 72.09
#   * latitude   (latitude) float32 34.12 33.87 33.62 33.37 ... 32.37 32.12 31.87
#   * time       (time) datetime64[ns] 1981-01-01 ... 2022-12-31T23:00:00
# Data variables:
#     elevtn     (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-03 14:57:44 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
filtered_data = nc_file.sel(time=slice("2021-01-01", "2021-12-31"))

# %%
filtered_data
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 14, latitude: 10, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 68.84 69.09 69.34 69.59 ... 71.59 71.84 72.09
#   * latitude   (latitude) float32 34.12 33.87 33.62 33.37 ... 32.37 32.12 31.87
#   * time       (time) datetime64[ns] 2021-01-01 ... 2021-12-31T23:00:00
# Data variables:
#     elevtn     (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-03 14:57:44 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
filtered_data.to_netcdf(path+'2021_oro.nc')

# %%
# # Specify the target EPSG code (4326 for WGS84)
# target_epsg = 4326
# # Define the target CRS
# target_crs = pyproj.CRS.from_string("EPSG:" + str(target_epsg))

# %%
# ds = filtered_data

# %%
# Get the source CRS from the variable attributes
# source_crs = pyproj.CRS(ds['longitude'].attrs['crs'])

# %%
# # Create the transformer from source to target CRS
# transformer = pyproj.Transformer.from_crs(source_crs, target_crs, always_xy=True)

# # Reproject the variables containing coordinate information
# for var_name, var in ds.variables.items():
#     if 'lon' in var.dims and 'lat' in var.dims:
#         lon, lat = var_name + ".lon", var_name + ".lat"
#         lon_new, lat_new = transformer.transform(ds[lon].values, ds[lat].values)
#         ds[lon] = xr.DataArray(lon_new, dims=ds[lon].dims)
#         ds[lat] = xr.DataArray(lat_new, dims=ds[lat].dims)

# %%
# df = filtered_data.to_dataframe().reset_index()

# %%
# df.max()
# Out:
# longitude              70.970001
# latitude               32.830002
# time         2022-01-01 23:00:00
# press_msl          102847.039062
# precip                  0.001191
# kout                   2996492.0
# temp                  293.743408
# kin                   515.821472
# dtype: object
